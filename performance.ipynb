# %%
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix

# Load predictions
df = pd.read_csv(r"C:\Varun\skin-detect-mvp\predictions_test.csv")

# Compare true vs predicted
y_true = df['ground_truth']
y_pred = df['pred']

print("\n=== Classification Report ===")
print(classification_report(y_true, y_pred, digits=3))

print("\n=== Confusion Matrix ===")
print(confusion_matrix(y_true, y_pred))
# Out:
# === Classification Report ===
#               precision    recall  f1-score   support
#
#        akiec      0.692     0.735     0.713        49
#          bcc      0.844     0.844     0.844        77
#          bkl      0.711     0.745     0.728       165
#           df      0.700     0.824     0.757        17
#          mel      0.594     0.665     0.627       167
#           nv      0.938     0.904     0.921      1006
#         vasc      0.800     0.909     0.851        22
#
#     accuracy                          0.850      1503
#    macro avg      0.754     0.804     0.777      1503
# weighted avg      0.857     0.850     0.853      1503
#
#
# === Confusion Matrix ===
# [[ 36   3   2   0   3   5   0]
#  [  0  65   6   0   1   5   0]
#  [  9   2 123   0  14  17   0]
#  [  1   0   0  14   1   1   0]
#  [  4   1  15   2 111  32   2]
#  [  2   6  26   4  56 909   3]
#  [  0   0   1   0   1   0  20]]
